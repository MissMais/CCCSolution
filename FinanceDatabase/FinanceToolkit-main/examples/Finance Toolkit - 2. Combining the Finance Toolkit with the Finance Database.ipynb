# %% [markdown]
# ![Finance Toolkit](https://github.com/JerBouma/FinanceToolkit/assets/46355364/198d47bd-e1b3-492d-acc4-5d9f02d1d009)
#
# The Finance Toolkit is complimented very well with the [Finance Database 🌎](https://github.com/JerBouma/FinanceDatabase), a database that features 300.000+ symbols containing Equities, ETFs, Funds, Indices, Currencies, Cryptocurrencies and Money Markets. By utilising both, it is possible to do a fully-fledged competitive analysis with the tickers found from the FinanceDatabase inputted into the Finance Toolkit.
#
# To install the **FinanceDatabase** it simply requires the following:
#
# ```
# pip install financedatabase -U
# ```
#
# From within Python use:
#
# ```python
# import financedatabase as fd
# ```
#
# For a detailed explanation of how to use the Finance Database, please see the GitHub page as found [here](https://github.com/JerBouma/FinanceDatabase).
#
# To be able to get started, you need to obtain an API Key from FinancialModelingPrep. This is used to gain access to 30+ years of financial statement both annually and quarterly. Note that the Free plan is limited to 250 requests each day, 5 years of data and only features companies listed on US exchanges.
#
# ___
#
# <b><div align="center">Obtain an API Key from FinancialModelingPrep <a href="https://site.financialmodelingprep.com/developer/docs/pricing/jeroen/">here</a>.</div></b>
# ___
#
# Through the link you are able to subscribe for the free plan and also premium plans at a **15% discount**. This is an affiliate link and thus supports the project at the same time. I have chosen FinancialModelingPrep as a source as I find it to be the most transparent, reliable and at an affordable price. When you notice that data is inaccurate or have any other issue related to the data, note that I simply provide the means to access this data and I am not responsible for the accuracy of the data itself. For this, use [their contact form](https://site.financialmodelingprep.com/contact) or provide the data yourself.

# %%
from financetoolkit import Toolkit
import financedatabase as fd

API_KEY = "2651e02dd0c5e229c372080ee1b5f6d4"

# %% [markdown]
# Lets start with searching for companies matching the industry `Road & Rail` in the `United States` that are defined as `Large Cap`.

# %%
# Initialize the Equities database
equities = fd.Equities()

# Obtain related companies
road_and_rail = equities.search(
    industry="Road & Rail",
    country="United States",
    market_cap="Large Cap",
    exclude_exchanges=True,
)

# Show the related DataFrame
road_and_rail
# Out:
#                                                    name  \
# symbol
# CSX                                     CSX Corporation
# KSU                                Kansas City Southern
# KSU-P                              Kansas City Southern
# NSC                        Norfolk Southern Corporation
# UNP                           Union Pacific Corporation
# WAB     Westinghouse Air Brake Technologies Corporation
#
#                                                   summary currency  \
# symbol
# CSX     CSX Corporation, together with its subsidiarie...      USD
# KSU     Kansas City Southern, a transportation holding...      USD
# KSU-P   Kansas City Southern, a transportation holding...      USD
# NSC     Norfolk Southern Corporation, together with it...      USD
# UNP     Union Pacific Corporation, through its subsidi...      USD
# WAB     Westinghouse Air Brake Technologies Corporatio...      USD
#
#              sector  industry_group     industry exchange  \
# symbol
# CSX     Industrials  Transportation  Road & Rail      NMS
# KSU     Industrials  Transportation  Road & Rail      NYQ
# KSU-P   Industrials  Transportation  Road & Rail      NYQ
# NSC     Industrials  Transportation  Road & Rail      NYQ
# UNP     Industrials  Transportation  Road & Rail      NYQ
# WAB     Industrials  Transportation  Road & Rail      NYQ
#
#                          market        country state          city  \
# symbol
# CSX        NASDAQ Global Select  United States    FL  Jacksonville
# KSU     New York Stock Exchange  United States    MO   Kansas City
# KSU-P   New York Stock Exchange  United States    MO   Kansas City
# NSC     New York Stock Exchange  United States    VA       Norfolk
# UNP     New York Stock Exchange  United States    NE         Omaha
# WAB     New York Stock Exchange  United States    PA    Pittsburgh
#
#            zipcode                         website market_cap          isin  \
# symbol
# CSX          32202              http://www.csx.com  Large Cap  US1264081035
# KSU          64105       http://www.kcsouthern.com  Large Cap           NaN
# KSU-P        64105       http://www.kcsouthern.com  Large Cap           NaN
# NSC     23510-2191  http://www.norfolksouthern.com  Large Cap  US6558441084
# UNP          68179               http://www.up.com  Large Cap  US9078181081
# WAB          15212       http://www.wabteccorp.com  Large Cap  US9297401088
#
#             cusip          figi composite_figi shareclass_figi
# symbol
# CSX     126408103  BBG000BGK1N1   BBG000BGJRC8    BBG001S5Q7Q3
# KSU           NaN           NaN            NaN             NaN
# KSU-P         NaN           NaN            NaN             NaN
# NSC     655844108  BBG000BQ5GM4   BBG000BQ5DS5    BBG001S5TQJ6
# UNP     907818108  BBG000BW3413   BBG000BW3299    BBG001S5X2M0
# WAB     929740108  BBG000BDDBD5   BBG000BDD940    BBG001S5XBT3

# %% [markdown]
# It appears that Kansas City Southern has been merged with Canadian Pacific Railway ([source](https://www.kcsouthern.com/media/news/news-releases/canadian-pacific-and-kansas-city-southern-combination-approved-by-u-s-surface-transportation-board)). Because of this, the ticker is taken out. The reason it still exists in the dataset of the FinanceDatabase is to control for survivorship bias.

# %%
road_and_rail = road_and_rail.drop(["KSU", "KSU-P"])

# %% [markdown]
# From here on, the tickers from the dataset are used to initialize the Finance Toolkit.

# %%
rail_companies = Toolkit(list(road_and_rail.index), api_key=API_KEY)

# %% [markdown]
# Let's start by showing the historical prices and plotting them accordingly.

# %%
# Collect Historical Data for each ticker
historical_data = rail_companies.get_historical_data()

# Show a portion of the dataset
display(historical_data)

# Plot the Cumulative Returns
historical_data["Cumulative Return"].plot(figsize=(15, 5), title="Cumulative Returns for the Rail Companies")

# %%
historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 2516 entries, 2013-10-16 to 2023-10-13
# Freq: D
# Data columns (total 60 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   (Open, CSX)                     2516 non-null   float64
#  1   (Open, NSC)                     2516 non-null   float64
#  2   (Open, UNP)                     2516 non-null   float64
#  3   (Open, WAB)                     2516 non-null   float64
#  4   (Open, Benchmark)               2516 non-null   float64
#  5   (High, CSX)                     2516 non-null   float64
#  6   (High, NSC)                     2516 non-null   float64
#  7   (High, UNP)                     2516 non-null   float64
#  8   (High, WAB)                     2516 non-null   float64
#  9   (High, Benchmark)               2516 non-null   float64
#  10  (Low, CSX)                      2516 non-null   float64
#  11  (Low, NSC)                      2516 non-null   float64
#  12  (Low, UNP)                      2516 non-null   float64
#  13  (Low, WAB)                      2516 non-null   float64
#  14  (Low, Benchmark)                2516 non-null   float64
#  15  (Close, CSX)                    2516 non-null   float64
#  16  (Close, NSC)                    2516 non-null   float64
#  17  (Close, UNP)                    2516 non-null   float64
#  18  (Close, WAB)                    2516 non-null   float64
#  19  (Close, Benchmark)              2516 non-null   float64
#  20  (Adj Close, CSX)                2516 non-null   float64
#  21  (Adj Close, NSC)                2516 non-null   float64
#  22  (Adj Close, UNP)                2516 non-null   float64
#  23  (Adj Close, WAB)                2516 non-null   float64
#  24  (Adj Close, Benchmark)          2516 non-null   float64
#  25  (Volume, CSX)                   2516 non-null   int64
#  26  (Volume, NSC)                   2516 non-null   int64
#  27  (Volume, UNP)                   2516 non-null   int64
#  28  (Volume, WAB)                   2516 non-null   int64
#  29  (Volume, Benchmark)             2516 non-null   int64
#  30  (Dividends, CSX)                2516 non-null   float64
#  31  (Dividends, NSC)                2516 non-null   float64
#  32  (Dividends, UNP)                2516 non-null   float64
#  33  (Dividends, WAB)                2516 non-null   float64
#  34  (Dividends, Benchmark)          2516 non-null   int64
#  35  (Return, CSX)                   2516 non-null   float64
#  36  (Return, NSC)                   2516 non-null   float64
#  37  (Return, UNP)                   2516 non-null   float64
#  38  (Return, WAB)                   2516 non-null   float64
#  39  (Return, Benchmark)             2516 non-null   float64
#  40  (Volatility, CSX)               2516 non-null   float64
#  41  (Volatility, NSC)               2516 non-null   float64
#  42  (Volatility, UNP)               2516 non-null   float64
#  43  (Volatility, WAB)               2516 non-null   float64
#  44  (Volatility, Benchmark)         2516 non-null   float64
#  45  (Excess Return, CSX)            2515 non-null   float64
#  46  (Excess Return, NSC)            2515 non-null   float64
#  47  (Excess Return, UNP)            2515 non-null   float64
#  48  (Excess Return, WAB)            2515 non-null   float64
#  49  (Excess Return, Benchmark)      2515 non-null   float64
#  50  (Excess Volatility, CSX)        2516 non-null   float64
#  51  (Excess Volatility, NSC)        2516 non-null   float64
#  52  (Excess Volatility, UNP)        2516 non-null   float64
#  53  (Excess Volatility, WAB)        2516 non-null   float64
#  54  (Excess Volatility, Benchmark)  2516 non-null   float64
#  55  (Cumulative Return, CSX)        2516 non-null   float64
#  56  (Cumulative Return, NSC)        2516 non-null   float64
#  57  (Cumulative Return, UNP)        2516 non-null   float64
#  58  (Cumulative Return, WAB)        2516 non-null   float64
#  59  (Cumulative Return, Benchmark)  2516 non-null   float64
# dtypes: float64(54), int64(6)
# memory usage: 1.2 MB

# %% [markdown]
# Let's have a look at the Balance Sheet Statement as well.

# %%
# Collect and show the Balance Sheet Statements
rail_companies.get_balance_sheet_statement()
# Out:
# Obtaining balance data: 100%|████████████████████████████████████████████████████████████| 4/4 [00:04<00:00,  1.24s/it]
# date                                        1985         1986        1987  \
# CSX Cash and Cash Equivalents        187000000.0  315000000.0 921000000.0
#     Short Term Investments                   0.0          0.0         0.0
#     Cash and Short Term Investments  187000000.0  315000000.0 921000000.0
#     Accounts Receivable             1299000000.0 1182000000.0 876000000.0
#     Inventory                        428000000.0  356000000.0 363000000.0
# ...                                          ...          ...         ...
# WAB Minority Interest                        NaN          NaN         NaN
#     Total Liabilities and Equity             NaN          NaN         NaN
#     Total Investments                        NaN          NaN         NaN
#     Total Debt                               NaN          NaN         NaN
#     Net Debt                                 NaN          NaN         NaN
#
# date                                       1988        1989        1990  \
# CSX Cash and Cash Equivalents       625000000.0 534000000.0 609000000.0
#     Short Term Investments                  0.0         0.0         0.0
#     Cash and Short Term Investments 625000000.0 534000000.0 609000000.0
#     Accounts Receivable             896000000.0 645000000.0 728000000.0
#     Inventory                       241000000.0 237000000.0 257000000.0
# ...                                         ...         ...         ...
# WAB Minority Interest                       NaN         NaN         NaN
#     Total Liabilities and Equity            NaN         NaN         NaN
#     Total Investments                       NaN         NaN         NaN
#     Total Debt                              NaN         NaN         NaN
#     Net Debt                                NaN         NaN         NaN
#
# date                                       1991        1992        1993  \
# CSX Cash and Cash Equivalents       465000000.0 530000000.0 298000000.0
#     Short Term Investments                  0.0         0.0         0.0
#     Cash and Short Term Investments 465000000.0 530000000.0 298000000.0
#     Accounts Receivable             728000000.0 605000000.0 668000000.0
#     Inventory                       206000000.0 189000000.0 199000000.0
# ...                                         ...         ...         ...
# WAB Minority Interest                       NaN         NaN         0.0
#     Total Liabilities and Equity            NaN         NaN 175600000.0
#     Total Investments                       NaN         NaN         0.0
#     Total Debt                              NaN         NaN 107900000.0
#     Net Debt                                NaN         NaN 107900000.0
#
# date                                       1994  ...         2013  \
# CSX Cash and Cash Equivalents       265000000.0  ...  592000000.0
#     Short Term Investments          270000000.0  ...  487000000.0
#     Cash and Short Term Investments 535000000.0  ... 1079000000.0
#     Accounts Receivable             706000000.0  ... 1052000000.0
#     Inventory                       211000000.0  ...  252000000.0
# ...                                         ...  ...          ...
# WAB Minority Interest                       0.0  ...    1908000.0
#     Total Liabilities and Equity    187700000.0  ... 2821997000.0
#     Total Investments                       0.0  ...          0.0
#     Total Debt                       78100000.0  ...  450709000.0
#     Net Debt                         77100000.0  ...  164949000.0
#
# date                                        2014         2015         2016  \
# CSX Cash and Cash Equivalents        669000000.0  628000000.0  603000000.0
#     Short Term Investments           292000000.0  810000000.0  417000000.0
#     Cash and Short Term Investments  961000000.0 1438000000.0 1020000000.0
#     Accounts Receivable             1129000000.0  982000000.0  938000000.0
#     Inventory                        273000000.0  350000000.0  407000000.0
# ...                                          ...          ...          ...
# WAB Minority Interest                  1056000.0    1732000.0  770848000.0
#     Total Liabilities and Equity    3303841000.0 3300335000.0 6581018000.0
#     Total Investments                -43953000.0  -71658000.0 -245680000.0
#     Total Debt                       521195000.0  695727000.0 1892776000.0
#     Net Debt                          95346000.0  469536000.0 1494292000.0
#
# date                                        2017         2018          2019  \
# CSX Cash and Cash Equivalents        401000000.0  858000000.0   958000000.0
#     Short Term Investments            18000000.0  253000000.0   996000000.0
#     Cash and Short Term Investments  419000000.0 1111000000.0  1954000000.0
#     Accounts Receivable              970000000.0 1010000000.0   986000000.0
#     Inventory                        372000000.0  263000000.0   261000000.0
# ...                                          ...          ...           ...
# WAB Minority Interest                 19664000.0    3944000.0    37100000.0
#     Total Liabilities and Equity    6579980000.0 8649234000.0 18886200000.0
#     Total Investments               -175902000.0 -198269000.0  -145300000.0
#     Total Debt                      1870528000.0 3792774000.0  4333600000.0
#     Net Debt                        1637127000.0 3211866000.0  3729400000.0
#
# date                                         2020          2021          2022
# CSX Cash and Cash Equivalents        3129000000.0  2239000000.0  1958000000.0
#     Short Term Investments              2000000.0    77000000.0   129000000.0
#     Cash and Short Term Investments  3131000000.0  2316000000.0  2087000000.0
#     Accounts Receivable               912000000.0  1148000000.0  1313000000.0
#     Inventory                         302000000.0   339000000.0   341000000.0
# ...                                           ...           ...           ...
# WAB Minority Interest                  30400000.0    38000000.0    45000000.0
#     Total Liabilities and Equity    18454500000.0 18454000000.0 18516000000.0
#     Total Investments                -168400000.0  -288000000.0           0.0
#     Total Debt                       3792200000.0  4056000000.0  4002000000.0
#     Net Debt                         3193500000.0  3583000000.0  3461000000.0
#
# [172 rows x 38 columns]

# %% [markdown]
# A very important financial ratio is the "Operating Ratio" for railroad companies. An operating ratio of 80 or lower has generally been seen as good but having a target as low as the mid-70s is even better. From the table below, it is clear that all companies except for WAB (Westinghouse Air Brake Technologies Corporation) are performing very well. This, however, makes sense since WAB is specialized on providing parts instead of actual railroad services.

# %%
# Collect and show the Balance Sheet Statements
rail_companies.ratios.get_operating_ratio()
# Out:
# Obtaining income data: 100%|█████████████████████████████████████████████████████████████| 4/4 [00:06<00:00,  1.54s/it]
# Obtaining cashflow data: 100%|███████████████████████████████████████████████████████████| 4/4 [00:04<00:00,  1.18s/it]
# The following data was not provided within the Toolkit class and thus was retrieved from FinancialModelingPrep: Income Statement, Cash Flow Statement.
# date   1985   1986   1987   1988   1989   1990   1991   1992   1993   1994  \
# CSX  0.8796 0.8366 0.8887 0.8803 0.8878 0.9007 0.9885 0.9695 0.8979 1.5787
# NSC   0.812 0.8278 0.9745 0.7881 0.8181  0.825 0.9748 0.8076 0.8071 0.8971
# UNP  0.8453 0.6641 0.6125 0.7541 0.7754 0.7701 0.7661 0.7764 0.8162 0.7894
# WAB     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN 0.7816 0.7433
#
# date  ...   2013   2014   2015   2016   2017   2018   2019   2020   2021  \
# CSX   ... 0.7095 0.7129 0.7049  0.698 0.6711 0.6164 0.5991 0.5896 0.5958
# NSC   ... 0.7104 0.6924 0.7256 0.6891 0.6601 0.6545 0.6469  0.654 0.6009
# UNP   ...  0.661 0.6351 0.6309 0.6353 0.6205  0.627  0.606 0.5989 0.5717
# WAB   ... 0.8296 0.8269 0.8163 0.8436 0.8915 0.8915 0.9191 0.9015  0.888
#
# date   2022
# CSX  0.6195
# NSC  0.6227
# UNP  0.6013
# WAB  0.8791
#
# [4 rows x 38 columns]

# %% [markdown]
# Other than this ratio, important other metrics are revenue growth, strong profit margins and efficient capital management. These can be explored further by looking into the income statement, the profit margin ratio and the current ratio.

# %%
# Obtain the income statement and select the revenues
revenues = rail_companies.get_income_statement().loc[:, "Revenue", :]

# Show revenue absolute numbers for each company
display(revenues)

# Show the revenue growth for each company
rail_companies.get_income_statement(growth=True).loc[:, "Revenue", :]
# Out:
# date         1985         1986         1987         1988         1989  \
# CSX  7320000000.0 6345000000.0 8043000000.0 7592000000.0 7745000000.0
# NSC  3825100000.0 4076400000.0 4112800000.0 4461600000.0 4536000000.0
# UNP  7798000000.0 6574000000.0 5943000000.0 6068000000.0 6492000000.0
# WAB           NaN          NaN          NaN          NaN          NaN
#
# date         1990         1991         1992         1993         1994  ...  \
# CSX  8205000000.0 8636000000.0 8734000000.0 8940000000.0 9608000000.0  ...
# NSC  4617000000.0 4451300000.0 4606600000.0 4460100000.0 4581300000.0  ...
# UNP  6964000000.0 7029000000.0 7294000000.0 7561000000.0 7798000000.0  ...
# WAB           NaN          NaN          NaN  285300000.0  347500000.0  ...
#
# date          2013          2014          2015          2016          2017  \
# CSX  12026000000.0 12669000000.0 11811000000.0 11069000000.0 11408000000.0
# NSC  11245000000.0 11624000000.0 10511000000.0  9888000000.0 10551000000.0
# UNP  21963000000.0 23988000000.0 21813000000.0 19941000000.0 21240000000.0
# WAB   2566392000.0  3044454000.0  3307998000.0  2931188000.0  3881756000.0
#
# date          2018          2019          2020          2021          2022
# CSX  12250000000.0 11937000000.0 10583000000.0 12522000000.0 14853000000.0
# NSC  11458000000.0 11296000000.0  9789000000.0 11142000000.0 12745000000.0
# UNP  22832000000.0 21708000000.0 19533000000.0 21804000000.0 24875000000.0
# WAB   4363547000.0  8200000000.0  7556100000.0  7822000000.0  8362000000.0
#
# [4 rows x 38 columns]
# date  1985    1986    1987    1988    1989    1990    1991    1992    1993  \
# CSX    NaN -0.1332  0.2676 -0.0561  0.0202  0.0594  0.0525  0.0113  0.0236
# NSC    NaN  0.0657  0.0089  0.0848  0.0167  0.0179 -0.0359  0.0349 -0.0318
# UNP    NaN  -0.157  -0.096   0.021  0.0699  0.0727  0.0093  0.0377  0.0366
# WAB    NaN -0.0466 -0.0098  0.0602 -0.0593 -0.0524  0.0289 -0.0123 -0.6502
#
# date   1994  ...   2013   2014    2015    2016   2017   2018    2019    2020  \
# CSX  0.0747  ...  0.023 0.0535 -0.0677 -0.0628 0.0306 0.0738 -0.0256 -0.1134
# NSC  0.0272  ... 0.0186 0.0337 -0.0958 -0.0593 0.0671  0.086 -0.0141 -0.1334
# UNP  0.0313  ... 0.0496 0.0922 -0.0907 -0.0858 0.0651  0.075 -0.0492 -0.1002
# WAB   0.218  ... 0.0733 0.1863  0.0866 -0.1139 0.3243 0.1241  0.8792 -0.0785
#
# date   2021   2022
# CSX  0.1832 0.1862
# NSC  0.1382 0.1439
# UNP  0.1163 0.1408
# WAB  0.0352  0.069
#
# [4 rows x 38 columns]

# %% [markdown]
# Profit Margins can be looked at from a variety of perspectives. The Finance Toolkit features Gross, Operating, Net Profit and EBT Profit Margins. With the `collect_profitability_ratios` functions within the `ratios` module these can be collected for each company accompanied with many other useful ratios. To provide an appropriate overview, the profitability ratios are only shown for `CSX`.

# %%
# Collect the profitability ratios and select the ratios for CSX
rail_companies.ratios.collect_profitability_ratios().loc["CSX"]
# Out:
# date                                           1985   1986   1987    1988  \
# Gross Margin                                 0.1762 0.2177 0.1789  0.1812
# Operating Margin                             0.1204 0.1634 0.1113  0.1197
# Net Profit Margin                           -0.0161 0.0659 0.0537 -0.0043
# Interest Coverage Ratio                         inf    inf    inf     inf
# Income Before Tax Profit Margin             -0.0359 0.1149 0.0848 -0.0079
# Effective Tax Rate                           0.5513 0.4266 0.3666  0.3667
# Return on Assets (ROA)                          NaN 0.0346 0.0334 -0.0025
# Return on Equity (ROE)                          NaN 0.0883 0.0888 -0.0081
# Return on Invested Capital (ROIC)               NaN    NaN    NaN     NaN
# Return on Capital Employed (ROCE)           -0.0276 0.0674 0.0602 -0.0055
# Return on Tangible Assets                       NaN 0.0215 0.0205 -0.0015
# Income Quality Ratio                            NaN    NaN    NaN     NaN
# Net Income per EBT                           0.4487 0.5734 0.6334     0.6
# Free Cash Flow to Operating Cash Flow Ratio     NaN    NaN    NaN     NaN
# EBT to EBIT Ratio                               1.0    1.0    1.0     1.0
# EBIT to Revenue                             -0.0359 0.1149 0.0848 -0.0072
#
# date                                          1989    1990     1991    1992  \
# Gross Margin                                0.1699   0.157   0.0695  0.0908
# Operating Margin                            0.1122  0.0993   0.0115  0.0305
# Net Profit Margin                           0.0554  0.0444  -0.0088  0.0023
# Interest Coverage Ratio                        inf     inf     -inf    -inf
# Income Before Tax Profit Margin             0.0893  0.0654  -0.0131 -0.0008
# Effective Tax Rate                          0.3829  0.3203   0.3274  3.8571
# Return on Assets (ROA)                      0.0339   0.029  -0.0059  0.0015
# Return on Equity (ROE)                      0.1292  0.1049  -0.0226  0.0065
# Return on Invested Capital (ROIC)           0.0504  0.0514   0.0069 -0.0789
# Return on Capital Employed (ROCE)           0.0696   0.051  -0.0109 -0.0007
# Return on Tangible Assets                   0.0196  0.0169  -0.0034  0.0009
# Income Quality Ratio                        2.3473  2.4423 -11.3947   46.95
# Net Income per EBT                          0.6182  0.6791   0.6726 -2.8571
# Free Cash Flow to Operating Cash Flow Ratio 0.1807 -0.0427   0.0023 -0.1086
# EBT to EBIT Ratio                              1.0     1.0      1.0     1.0
# EBIT to Revenue                             0.0896  0.0653  -0.0131 -0.0008
#
# date                                          1993   1994  ...   2013   2014  \
# Gross Margin                                0.1661   0.41  ... 0.2888 0.2852
# Operating Margin                            0.1021 0.1282  ... 0.2888 0.2852
# Net Profit Margin                           0.0402 0.0679  ...  0.155 0.1521
# Interest Coverage Ratio                        inf    inf  ... 8.1441 8.7413
# Income Before Tax Profit Margin             0.0708 0.1047  ...  0.243 0.2403
# Effective Tax Rate                          0.4329 0.3519  ... 0.3621  0.367
# Return on Assets (ROA)                      0.0271  0.048  ... 0.0598 0.0594
# Return on Equity (ROE)                      0.1167 0.1887  ... 0.1911 0.1778
# Return on Invested Capital (ROIC)           0.0454 0.0804  ... 0.0808  0.079
# Return on Capital Employed (ROCE)           0.0568 0.0897  ... 0.1187  0.116
# Return on Tangible Assets                   0.0153 0.0275  ... 0.0354 0.0357
# Income Quality Ratio                        2.6797 2.0337  ... 1.7527 1.7348
# Net Income per EBT                          0.5671 0.6481  ... 0.6379  0.633
# Free Cash Flow to Operating Cash Flow Ratio 0.2017 0.3401  ...  0.292 0.2674
# EBT to EBIT Ratio                              1.0    1.0  ... 0.8387 0.8481
# EBIT to Revenue                             0.0708 0.1047  ... 0.2897 0.2833
#
# date                                          2015   2016    2017   2018  \
# Gross Margin                                0.3034 0.3062  0.3307 0.3896
# Operating Margin                            0.3034 0.3062  0.3214 0.3975
# Net Profit Margin                           0.1666 0.1548  0.4796 0.2701
# Interest Coverage Ratio                     8.8088 8.1002  9.1245 9.7027
# Income Before Tax Profit Margin             0.2657 0.2476  0.2754 0.3513
# Effective Tax Rate                          0.3728 0.3747 -0.7412 0.2312
# Return on Assets (ROA)                      0.0578 0.0487  0.1538 0.0913
# Return on Equity (ROE)                      0.1723 0.1467  0.4142 0.2424
# Return on Invested Capital (ROIC)           0.0769  0.066  0.4346 0.1159
# Return on Capital Employed (ROCE)           0.1113 0.0995   0.109  0.142
# Return on Tangible Assets                   0.0347 0.0292  0.0944 0.0563
# Income Quality Ratio                        1.7124 1.7742  0.6346 1.4025
# Net Income per EBT                          0.6272 0.6253  1.7412 0.7688
# Free Cash Flow to Operating Cash Flow Ratio 0.2398 0.2114  0.4124  0.624
# EBT to EBIT Ratio                           0.8523 0.8256   0.852 0.8707
# EBIT to Revenue                             0.3117 0.2999  0.3233 0.4035
#
# date                                          2019   2020   2021   2022
# Gross Margin                                0.4083 0.4122 0.4105 0.3895
# Operating Margin                            0.4159 0.4122 0.4467 0.4055
# Net Profit Margin                            0.279 0.2613 0.3019 0.2805
# Interest Coverage Ratio                     8.6866 7.6446 9.1953 9.9973
# Income Before Tax Profit Margin             0.3616 0.3427 0.3954 0.3645
# Effective Tax Rate                          0.2282 0.2377 0.2363 0.2305
# Return on Assets (ROA)                      0.0888 0.0709 0.0941 0.1011
# Return on Equity (ROE)                      0.2726 0.2214 0.2842 0.3189
# Return on Invested Capital (ROIC)            0.114 0.0938 0.1182 0.1276
# Return on Capital Employed (ROCE)           0.1399  0.116 0.1481 0.1561
# Return on Tangible Assets                   0.0531 0.0422 0.0563 0.0599
# Income Quality Ratio                         1.456 1.5418 1.3486 1.3488
# Net Income per EBT                          0.7718 0.7623 0.7637 0.7695
# Free Cash Flow to Operating Cash Flow Ratio 0.6584 0.6186 0.6488 0.6204
# EBT to EBIT Ratio                           0.8541 0.8279 0.8727 0.8795
# EBIT to Revenue                             0.4233  0.414  0.453 0.4145
#
# [16 rows x 38 columns]

# %% [markdown]
# Capital Management can be viewed from multiple angles including liquidity, accounts receivable, inventory and accounts payable management. These lead to the Operating and Cash Conversion Cycles. All of these ratios can be found within the `collect_efficiency_ratios` and `collect_liquidity_ratios` functions within the `ratios` module.

# %%
# Collect the liquidity ratios for all companies
rail_companies.ratios.collect_liquidity_ratios()
# Out:
# date                                          1985         1986         1987  \
# CSX Current Ratio                           1.0502       1.1375       1.2592
#     Quick Ratio                             0.7613       0.8105       0.9468
#     Cash Ratio                              0.0958       0.1705       0.4852
#     Working Capital                     98000000.0  254000000.0  492000000.0
#     Operating Cash Flow Ratio                  NaN          NaN          NaN
#     Operating Cash Flow to Sales Ratio         NaN          NaN          NaN
#     Short Term Coverage Ratio                  NaN          NaN          NaN
# NSC Current Ratio                           1.4349       1.6452       1.5654
#     Quick Ratio                             1.2999         1.44       1.3928
#     Cash Ratio                              0.7525       0.6868       0.6602
#     Working Capital                    622600000.0  679900000.0  685000000.0
#     Operating Cash Flow Ratio                  NaN          NaN          NaN
#     Operating Cash Flow to Sales Ratio         NaN          NaN          NaN
#     Short Term Coverage Ratio                  NaN          NaN          NaN
# UNP Current Ratio                           1.0537       0.8666        0.892
#     Quick Ratio                             0.7221       0.5209       0.5629
#     Cash Ratio                              0.2701       0.1675       0.1054
#     Working Capital                     90000000.0 -239000000.0 -169000000.0
#     Operating Cash Flow Ratio                  NaN          NaN          NaN
#     Operating Cash Flow to Sales Ratio         NaN          NaN          NaN
#     Short Term Coverage Ratio                  NaN          NaN          NaN
# WAB Current Ratio                              NaN          NaN          NaN
#     Quick Ratio                                NaN          NaN          NaN
#     Cash Ratio                                 NaN          NaN          NaN
#     Working Capital                            NaN          NaN          NaN
#     Operating Cash Flow Ratio                  NaN          NaN          NaN
#     Operating Cash Flow to Sales Ratio         NaN          NaN          NaN
#     Short Term Coverage Ratio                  NaN          NaN          NaN
#
# date                                           1988         1989         1990  \
# CSX Current Ratio                            0.7955        0.734        0.749
#     Quick Ratio                              0.4969       0.5058       0.5805
#     Cash Ratio                               0.2042       0.2291       0.2644
#     Working Capital                    -626000000.0 -620000000.0 -578000000.0
#     Operating Cash Flow Ratio                   NaN        0.432        0.386
#     Operating Cash Flow to Sales Ratio          NaN         0.13       0.1083
#     Short Term Coverage Ratio                   NaN      -1.0223      -0.9251
# NSC Current Ratio                            1.5522       1.4167       1.2734
#     Quick Ratio                              1.3423       0.9149       0.9057
#     Cash Ratio                               0.5337       0.1792       0.2841
#     Working Capital                     659700000.0  502900000.0  375000000.0
#     Operating Cash Flow Ratio                   NaN       0.9175       0.7251
#     Operating Cash Flow to Sales Ratio          NaN       0.2441       0.2154
#     Short Term Coverage Ratio                   NaN       8.3248       7.0099
# UNP Current Ratio                            0.8962       0.6718       0.6918
#     Quick Ratio                              0.6188       0.3549       0.3936
#     Cash Ratio                                0.236       0.1001       0.0932
#     Working Capital                    -193000000.0 -613000000.0 -559000000.0
#     Operating Cash Flow Ratio                   NaN       0.7939       0.8087
#     Operating Cash Flow to Sales Ratio          NaN       0.2284       0.2107
#     Short Term Coverage Ratio                   NaN       3.9759       3.2966
# WAB Current Ratio                               NaN          NaN          NaN
#     Quick Ratio                                 NaN          NaN          NaN
#     Cash Ratio                                  NaN          NaN          NaN
#     Working Capital                             NaN          NaN          NaN
#     Operating Cash Flow Ratio                   NaN          NaN          NaN
#     Operating Cash Flow to Sales Ratio          NaN          NaN          NaN
#     Short Term Coverage Ratio                   NaN          NaN          NaN
#
# date                                           1991         1992         1993  \
# CSX Current Ratio                            0.6197       0.6232       0.6905
#     Quick Ratio                              0.4816       0.4978       0.4246
#     Cash Ratio                               0.1877       0.2325        0.131
#     Working Capital                    -942000000.0 -859000000.0 -704000000.0
#     Operating Cash Flow Ratio                0.3496       0.4118       0.4229
#     Operating Cash Flow to Sales Ratio       0.1003       0.1075       0.1076
#     Short Term Coverage Ratio               -0.7563      -0.7382      -0.8761
# NSC Current Ratio                            1.0958       1.1816       1.3052
#     Quick Ratio                              0.6586       0.9528       0.8249
#     Cash Ratio                                0.118       0.0945       0.0672
#     Working Capital                     128500000.0  214700000.0  365600000.0
#     Operating Cash Flow Ratio                0.5686       0.8103       0.7301
#     Operating Cash Flow to Sales Ratio       0.1713        0.208       0.1961
#     Short Term Coverage Ratio                7.8598       2.1748       2.6969
# UNP Current Ratio                            0.6253       0.6627       0.6616
#     Quick Ratio                              0.3533       0.3935       0.3657
#     Cash Ratio                               0.0771       0.1176       0.0541
#     Working Capital                    -700000000.0 -703000000.0 -707000000.0
#     Operating Cash Flow Ratio                0.7452       0.7965       0.7482
#     Operating Cash Flow to Sales Ratio        0.198       0.2276       0.2067
#     Short Term Coverage Ratio                4.0465       5.6081        3.669
# WAB Current Ratio                               NaN          NaN       1.6159
#     Quick Ratio                                 NaN          NaN       0.8584
#     Cash Ratio                                  NaN          NaN          0.0
#     Working Capital                             NaN          NaN   28700000.0
#     Operating Cash Flow Ratio                   NaN          NaN        0.794
#     Operating Cash Flow to Sales Ratio          NaN          NaN       0.1297
#     Short Term Coverage Ratio                   NaN          NaN       0.6368
#
# date                                           1994  ...        2013  \
# CSX Current Ratio                            0.6647  ...      1.0734
#     Quick Ratio                              0.4954  ...      0.8791
#     Cash Ratio                               0.2136  ...      0.4451
#     Working Capital                    -840000000.0  ... 178000000.0
#     Operating Cash Flow Ratio                0.5293  ...      1.3478
#     Operating Cash Flow to Sales Ratio        0.138  ...      0.2717
#     Short Term Coverage Ratio               -1.2335  ...       9.415
# NSC Current Ratio                            1.1817  ...      1.3341
#     Quick Ratio                               0.913  ...      1.1215
#     Cash Ratio                                0.271  ...      0.6772
#     Working Capital                     205700000.0  ... 770000000.0
#     Operating Cash Flow Ratio                 1.011  ...      1.3354
#     Operating Cash Flow to Sales Ratio       0.2498  ...      0.2737
#     Short Term Coverage Ratio               13.5581  ...      -171.0
# UNP Current Ratio                            0.7273  ...      1.0525
#     Quick Ratio                              0.4232  ...      0.7507
#     Cash Ratio                               0.0483  ...      0.3777
#     Working Capital                    -683000000.0  ... 199000000.0
#     Operating Cash Flow Ratio                0.7621  ...      1.7998
#     Operating Cash Flow to Sales Ratio       0.2448  ...      0.3107
#     Short Term Coverage Ratio                2.4134  ...      5.3979
# WAB Current Ratio                            2.0708  ...      2.3007
#     Quick Ratio                              1.1027  ...      1.4502
#     Cash Ratio                               0.0228  ...      0.4932
#     Working Capital                      46900000.0  ... 753647000.0
#     Operating Cash Flow Ratio                0.9977  ...      0.4067
#     Operating Cash Flow to Sales Ratio       0.1258  ...      0.0918
#     Short Term Coverage Ratio                0.6061  ...      0.3734
#
# date                                          2014         2015         2016  \
# CSX Current Ratio                           1.2207       1.5195       1.2191
#     Quick Ratio                             0.9919       1.2398       0.9598
#     Cash Ratio                              0.4561       0.7367          0.5
#     Working Capital                    465000000.0 1014000000.0  447000000.0
#     Operating Cash Flow Ratio               1.5866       1.7264       1.4907
#     Operating Cash Flow to Sales Ratio      0.2639       0.2853       0.2747
#     Short Term Coverage Ratio               6.0018       5.9331       5.6419
# NSC Current Ratio                           1.5607       1.1802       0.9795
#     Quick Ratio                             1.1393       0.9175       0.8127
#     Cash Ratio                              0.5466       0.4935       0.4087
#     Working Capital                    998000000.0  402000000.0  -48000000.0
#     Operating Cash Flow Ratio               1.6022       1.2896       1.2971
#     Operating Cash Flow to Sales Ratio      0.2454       0.2737       0.3068
#     Short Term Coverage Ratio              49.1724      22.8333    -233.3846
# UNP Current Ratio                           1.2428       1.2882       0.9879
#     Quick Ratio                             0.8491       0.8568       0.7129
#     Cash Ratio                              0.4212       0.4339       0.3673
#     Working Capital                    914000000.0  924000000.0  -44000000.0
#     Operating Cash Flow Ratio               1.9615       2.2907       2.0673
#     Operating Cash Flow to Sales Ratio      0.3079       0.3367       0.3774
#     Short Term Coverage Ratio               5.1072        5.444       7.3775
# WAB Current Ratio                           2.2169       2.4256       1.9823
#     Quick Ratio                             1.4308        1.241        0.927
#     Cash Ratio                              0.5764       0.3403       0.2755
#     Working Capital                    899062000.0  947672000.0 1420992000.0
#     Operating Cash Flow Ratio               0.6394       0.6743       0.3106
#     Operating Cash Flow to Sales Ratio      0.1552       0.1355       0.1533
#     Short Term Coverage Ratio               0.6364       0.5915       0.4196
#
# date                                           2017         2018         2019  \
# CSX Current Ratio                            1.0111       1.3394       1.5239
#     Quick Ratio                              0.7334       1.1076       1.3668
#     Cash Ratio                               0.2212       0.5802       0.9084
#     Working Capital                      21000000.0  650000000.0 1127000000.0
#     Operating Cash Flow Ratio                1.8332       2.4235       2.2548
#     Operating Cash Flow to Sales Ratio       0.3043       0.3789       0.4063
#     Short Term Coverage Ratio                7.0141      14.3241      23.7745
# NSC Current Ratio                            0.8444       0.7186       0.9048
#     Quick Ratio                              0.6464       0.5276       0.6522
#     Cash Ratio                               0.2711       0.1382       0.2522
#     Working Capital                    -396000000.0 -729000000.0 -219000000.0
#     Operating Cash Flow Ratio                1.2782       1.4381       1.6922
#     Operating Cash Flow to Sales Ratio       0.3083       0.3252       0.3445
#     Short Term Coverage Ratio              -14.5223     -12.8927     -14.7424
# UNP Current Ratio                            1.0251       0.8999        0.795
#     Quick Ratio                              0.7256       0.6675       0.5714
#     Cash Ratio                               0.3465       0.2882       0.2048
#     Working Capital                      99000000.0 -463000000.0 -892000000.0
#     Operating Cash Flow Ratio                1.8355       1.8776       1.9786
#     Operating Cash Flow to Sales Ratio       0.3404       0.3804       0.3966
#     Short Term Coverage Ratio                5.8828       5.3452       5.3907
# WAB Current Ratio                            1.4397       2.7022       1.2867
#     Quick Ratio                                0.89       1.0492       0.6962
#     Cash Ratio                               0.1483       0.3528       0.1855
#     Working Capital                     691783000.0 2802977000.0  934100000.0
#     Operating Cash Flow Ratio                  0.12       0.1911       0.3117
#     Operating Cash Flow to Sales Ratio       0.0486       0.0721       0.1238
#     Short Term Coverage Ratio                0.1391       0.2244       0.4455
#
# date                                           2020          2021  \
# CSX Current Ratio                            2.1996        1.7344
#     Quick Ratio                              2.0025        1.5513
#     Cash Ratio                               1.5508        1.0372
#     Working Capital                    2422000000.0  1640000000.0
#     Operating Cash Flow Ratio                2.1114        2.2835
#     Operating Cash Flow to Sales Ratio       0.4028        0.4072
#     Short Term Coverage Ratio               10.5259        9.7309
# NSC Current Ratio                            1.0731        0.8596
#     Quick Ratio                              0.9088          0.72
#     Cash Ratio                               0.5162        0.3328
#     Working Capital                     158000000.0  -354000000.0
#     Operating Cash Flow Ratio                1.6838        1.6878
#     Operating Cash Flow to Sales Ratio       0.3715        0.3819
#     Short Term Coverage Ratio               68.6226      -27.1019
# UNP Current Ratio                            1.0098        0.6182
#     Quick Ratio                              0.8061        0.4749
#     Cash Ratio                               0.4455        0.1751
#     Working Capital                      41000000.0 -2193000000.0
#     Operating Cash Flow Ratio                2.0465        1.5724
#     Operating Cash Flow to Sales Ratio       0.4372        0.4142
#     Short Term Coverage Ratio                5.5781        5.6769
# WAB Current Ratio                            1.2026        1.3168
#     Quick Ratio                              0.6234        0.6701
#     Cash Ratio                               0.1856        0.1625
#     Working Capital                     653500000.0   922000000.0
#     Operating Cash Flow Ratio                0.2429        0.3687
#     Operating Cash Flow to Sales Ratio       0.1037        0.1372
#     Short Term Coverage Ratio                0.3653        0.4981
#
# date                                            2022
# CSX Current Ratio                             1.5577
#     Quick Ratio                                1.376
#     Cash Ratio                                0.8446
#     Working Capital                     1378000000.0
#     Operating Cash Flow Ratio                  2.274
#     Operating Cash Flow to Sales Ratio        0.3783
#     Short Term Coverage Ratio                10.7233
# NSC Current Ratio                             0.7576
#     Quick Ratio                               0.6055
#     Cash Ratio                                0.1721
#     Working Capital                     -642000000.0
#     Operating Cash Flow Ratio                 1.5938
#     Operating Cash Flow to Sales Ratio        0.3313
#     Short Term Coverage Ratio                39.0926
# UNP Current Ratio                             0.7159
#     Quick Ratio                               0.5272
#     Cash Ratio                                0.1846
#     Working Capital                    -1568000000.0
#     Operating Cash Flow Ratio                  1.696
#     Operating Cash Flow to Sales Ratio        0.3764
#     Short Term Coverage Ratio                  5.066
# WAB Current Ratio                             1.2481
#     Quick Ratio                               0.5942
#     Cash Ratio                                 0.156
#     Working Capital                      860000000.0
#     Operating Cash Flow Ratio                 0.2994
#     Operating Cash Flow to Sales Ratio        0.1241
#     Short Term Coverage Ratio                 0.4609
#
# [28 rows x 38 columns]

# %%
# Collect the efficiency ratios for all companies
rail_companies.ratios.collect_efficiency_ratios()
# Out:
# date                                             1985     1986     1987  \
# CSX Days of Inventory Outstanding (DIO)           NaN  28.8235  19.8694
#     Days of Sales Outstanding (DSO)               NaN  71.3605  46.6971
#     Operating Cycle (CC)                          NaN  100.184  66.5665
#     Days of Accounts Payable Outstanding (DPO)    NaN      0.0      0.0
#     Cash Conversion Cycle (CCC)                   NaN  100.184  66.5665
#     Receivables Turnover                          NaN   0.1955   0.1279
#     Inventory Turnover Ratio                      NaN  12.6633    18.37
#     Accounts Payable Turnover Ratio               NaN      inf      inf
#     SGA-to-Revenue Ratio                          0.0      0.0      0.0
#     Fixed Asset Turnover                          NaN   0.6344   0.7516
#     Asset Turnover Ratio                          NaN   0.5254   0.6213
#     Operating Ratio                            0.8796   0.8366   0.8887
# NSC Days of Inventory Outstanding (DIO)           NaN   8.9085   7.5613
#     Days of Sales Outstanding (DSO)               NaN    70.62  74.6099
#     Operating Cycle (CC)                          NaN  79.5286  82.1712
#     Days of Accounts Payable Outstanding (DPO)    NaN      0.0      0.0
#     Cash Conversion Cycle (CCC)                   NaN  79.5286  82.1712
#     Receivables Turnover                          NaN   0.1935   0.2044
#     Inventory Turnover Ratio                      NaN  40.9719  48.2721
#     Accounts Payable Turnover Ratio               NaN      inf      inf
#     SGA-to-Revenue Ratio                       0.0909    0.096   0.2368
#     Fixed Asset Turnover                          NaN   0.5182   0.5167
#     Asset Turnover Ratio                          NaN   0.4176   0.4208
#     Operating Ratio                             0.812   0.8278   0.9745
# UNP Days of Inventory Outstanding (DIO)           NaN  63.2017  89.3085
#     Days of Sales Outstanding (DSO)               NaN  38.6154  41.4256
#     Operating Cycle (CC)                          NaN 101.8171 130.7341
#     Days of Accounts Payable Outstanding (DPO)    NaN      0.0      0.0
#     Cash Conversion Cycle (CCC)                   NaN 101.8171 130.7341
#     Receivables Turnover                          NaN   0.1058   0.1135
#     Inventory Turnover Ratio                      NaN   5.7752    4.087
#     Accounts Payable Turnover Ratio               NaN      inf      inf
#     SGA-to-Revenue Ratio                       0.2887   0.2711   0.3648
#     Fixed Asset Turnover                          NaN   0.7203   0.6311
#     Asset Turnover Ratio                          NaN   0.6095   0.5457
#     Operating Ratio                            0.8453   0.6641   0.6125
# WAB Days of Inventory Outstanding (DIO)           NaN      NaN      NaN
#     Days of Sales Outstanding (DSO)               NaN      NaN      NaN
#     Operating Cycle (CC)                          NaN      NaN      NaN
#     Days of Accounts Payable Outstanding (DPO)    NaN      NaN      NaN
#     Cash Conversion Cycle (CCC)                   NaN      NaN      NaN
#     Receivables Turnover                          NaN      NaN      NaN
#     Inventory Turnover Ratio                      NaN      NaN      NaN
#     Accounts Payable Turnover Ratio               NaN      NaN      NaN
#     SGA-to-Revenue Ratio                          NaN      NaN      NaN
#     Fixed Asset Turnover                          NaN      NaN      NaN
#     Asset Turnover Ratio                          NaN      NaN      NaN
#     Operating Ratio                               NaN      NaN      NaN
#
# date                                              1988    1989     1990  \
# CSX Days of Inventory Outstanding (DIO)        17.7333  13.569  13.0338
#     Days of Sales Outstanding (DSO)            42.5962 36.3115   30.539
#     Operating Cycle (CC)                       60.3294 49.8805  43.5728
#     Days of Accounts Payable Outstanding (DPO)     0.0 52.9985 100.6032
#     Cash Conversion Cycle (CCC)                60.3294  -3.118 -57.0304
#     Receivables Turnover                        0.1167  0.0995   0.0837
#     Inventory Turnover Ratio                   20.5828 26.8996   28.004
#     Accounts Payable Turnover Ratio                inf   6.887   3.6281
#     SGA-to-Revenue Ratio                           0.0     0.0      0.0
#     Fixed Asset Turnover                        0.7085  0.7314   0.7574
#     Asset Turnover Ratio                        0.5783  0.6117   0.6537
#     Operating Ratio                             0.8803  0.8878   0.9007
# NSC Days of Inventory Outstanding (DIO)        10.9907  8.0741   8.7747
#     Days of Sales Outstanding (DSO)            75.8208 74.5852  68.7982
#     Operating Cycle (CC)                       86.8115 82.6593  77.5729
#     Days of Accounts Payable Outstanding (DPO)     0.0 50.5802  97.2215
#     Cash Conversion Cycle (CCC)                86.8115  32.079 -19.6486
#     Receivables Turnover                        0.2077  0.2043   0.1885
#     Inventory Turnover Ratio                   33.2098 45.2064   41.597
#     Accounts Payable Turnover Ratio                inf  7.2163   3.7543
#     SGA-to-Revenue Ratio                        0.2642  0.0898   0.0892
#     Fixed Asset Turnover                        0.5541   0.542   0.5334
#     Asset Turnover Ratio                        0.4494  0.4468   0.4446
#     Operating Ratio                             0.7881  0.8181    0.825
# UNP Days of Inventory Outstanding (DIO)        39.6186 45.8634  40.0185
#     Days of Sales Outstanding (DSO)            42.9483 33.3965  26.7565
#     Operating Cycle (CC)                       82.5668 79.2599   66.775
#     Days of Accounts Payable Outstanding (DPO)     0.0 31.6449  56.1051
#     Cash Conversion Cycle (CCC)                82.5668  47.615  10.6699
#     Receivables Turnover                        0.1177  0.0915   0.0733
#     Inventory Turnover Ratio                    9.2129  7.9584   9.1208
#     Accounts Payable Turnover Ratio                inf 11.5342   6.5056
#     SGA-to-Revenue Ratio                        0.3139  0.3809   0.3655
#     Fixed Asset Turnover                        0.6043  0.5966   0.6049
#     Asset Turnover Ratio                        0.5243  0.5259   0.5454
#     Operating Ratio                             0.7541  0.7754   0.7701
# WAB Days of Inventory Outstanding (DIO)            NaN     NaN      NaN
#     Days of Sales Outstanding (DSO)                NaN     NaN      NaN
#     Operating Cycle (CC)                           NaN     NaN      NaN
#     Days of Accounts Payable Outstanding (DPO)     NaN     NaN      NaN
#     Cash Conversion Cycle (CCC)                    NaN     NaN      NaN
#     Receivables Turnover                           NaN     NaN      NaN
#     Inventory Turnover Ratio                       NaN     NaN      NaN
#     Accounts Payable Turnover Ratio                NaN     NaN      NaN
#     SGA-to-Revenue Ratio                           NaN     NaN      NaN
#     Fixed Asset Turnover                           NaN     NaN      NaN
#     Asset Turnover Ratio                           NaN     NaN      NaN
#     Operating Ratio                                NaN     NaN      NaN
#
# date                                               1991     1992     1993  \
# CSX Days of Inventory Outstanding (DIO)         10.5149   9.0779   9.4983
#     Days of Sales Outstanding (DSO)             30.7689  27.8535  25.9869
#     Operating Cycle (CC)                        41.2837  36.9314  35.4852
#     Days of Accounts Payable Outstanding (DPO)   91.409  95.2604  98.6797
#     Cash Conversion Cycle (CCC)                -50.1252  -58.329 -63.1946
#     Receivables Turnover                         0.0843   0.0763   0.0712
#     Inventory Turnover Ratio                    34.7127  40.2076  38.4278
#     Accounts Payable Turnover Ratio               3.993   3.8316   3.6988
#     SGA-to-Revenue Ratio                            0.0      0.0      0.0
#     Fixed Asset Turnover                         0.7731   0.7631   0.7616
#     Asset Turnover Ratio                         0.6746   0.6758   0.6755
#     Operating Ratio                              0.9885   0.9695   0.8979
# NSC Days of Inventory Outstanding (DIO)           7.684  15.1241  16.3693
#     Days of Sales Outstanding (DSO)             64.6804  68.9258  78.6656
#     Operating Cycle (CC)                        72.3645  84.0499  95.0349
#     Days of Accounts Payable Outstanding (DPO)  75.7624 135.4562 141.7771
#     Cash Conversion Cycle (CCC)                 -3.3979 -51.4063 -46.7423
#     Receivables Turnover                         0.1772   0.1888   0.2155
#     Inventory Turnover Ratio                     47.501  24.1337  22.2978
#     Accounts Payable Turnover Ratio              4.8177   2.6946   2.5745
#     SGA-to-Revenue Ratio                          0.083   0.3257   0.3385
#     Fixed Asset Turnover                           0.51    0.521   0.4967
#     Asset Turnover Ratio                         0.4307   0.4484   0.4264
#     Operating Ratio                              0.9748   0.8076   0.8071
# UNP Days of Inventory Outstanding (DIO)         36.6102  36.8799  34.9768
#     Days of Sales Outstanding (DSO)             27.5477  27.2974   29.592
#     Operating Cycle (CC)                        64.1579  64.1773  64.5688
#     Days of Accounts Payable Outstanding (DPO)  58.0252  72.5726  70.5178
#     Cash Conversion Cycle (CCC)                  6.1326  -8.3953   -5.949
#     Receivables Turnover                         0.0755   0.0748   0.0811
#     Inventory Turnover Ratio                     9.9699    9.897  10.4355
#     Accounts Payable Turnover Ratio              6.2904   5.0294    5.176
#     SGA-to-Revenue Ratio                         0.3581   0.3573   0.3484
#     Fixed Asset Turnover                         0.5862   0.5865   0.5742
#     Asset Turnover Ratio                         0.5324   0.5319   0.5197
#     Operating Ratio                              0.7661   0.7764   0.8162
# WAB Days of Inventory Outstanding (DIO)             NaN      NaN      NaN
#     Days of Sales Outstanding (DSO)                 NaN      NaN      NaN
#     Operating Cycle (CC)                            NaN      NaN      NaN
#     Days of Accounts Payable Outstanding (DPO)      NaN      NaN      NaN
#     Cash Conversion Cycle (CCC)                     NaN      NaN      NaN
#     Receivables Turnover                            NaN      NaN      NaN
#     Inventory Turnover Ratio                        NaN      NaN      NaN
#     Accounts Payable Turnover Ratio                 NaN      NaN      NaN
#     SGA-to-Revenue Ratio                            NaN      NaN    0.095
#     Fixed Asset Turnover                            NaN      NaN      NaN
#     Asset Turnover Ratio                            NaN      NaN      NaN
#     Operating Ratio                                 NaN      NaN   0.7816
#
# date                                                1994  ...     2013  \
# CSX Days of Inventory Outstanding (DIO)           13.199  ...  11.2235
#     Days of Sales Outstanding (DSO)              26.0986  ...  30.5634
#     Operating Cycle (CC)                         39.2975  ...  41.7869
#     Days of Accounts Payable Outstanding (DPO)  127.3862  ...  42.0563
#     Cash Conversion Cycle (CCC)                 -88.0887  ...  -0.2694
#     Receivables Turnover                          0.0715  ...   0.0837
#     Inventory Turnover Ratio                     27.6537  ...  32.5209
#     Accounts Payable Turnover Ratio               2.8653  ...   8.6788
#     SGA-to-Revenue Ratio                          0.4465  ...      0.0
#     Fixed Asset Turnover                          0.8037  ...   0.4223
#     Asset Turnover Ratio                          0.7079  ...   0.3857
#     Operating Ratio                               1.5787  ...   0.7095
# NSC Days of Inventory Outstanding (DIO)          21.9352  ...  11.1896
#     Days of Sales Outstanding (DSO)              65.0998  ...  34.6174
#     Operating Cycle (CC)                         87.0349  ...   45.807
#     Days of Accounts Payable Outstanding (DPO)  225.2753  ...  66.9591
#     Cash Conversion Cycle (CCC)                -138.2403  ... -21.1522
#     Receivables Turnover                          0.1784  ...   0.0948
#     Inventory Turnover Ratio                     16.6399  ...  32.6196
#     Accounts Payable Turnover Ratio               1.6202  ...   5.4511
#     SGA-to-Revenue Ratio                          0.3583  ...   0.0058
#     Fixed Asset Turnover                          0.5033  ...   0.3911
#     Asset Turnover Ratio                          0.4341  ...    0.358
#     Operating Ratio                               0.8971  ...   0.7104
# UNP Days of Inventory Outstanding (DIO)          31.5288  ...  17.5316
#     Days of Sales Outstanding (DSO)              37.2115  ...  22.8094
#     Operating Cycle (CC)                         68.7403  ...   40.341
#     Days of Accounts Payable Outstanding (DPO)     52.27  ...  21.7376
#     Cash Conversion Cycle (CCC)                  16.4703  ...  18.6034
#     Receivables Turnover                          0.1019  ...   0.0625
#     Inventory Turnover Ratio                     11.5767  ...  20.8195
#     Accounts Payable Turnover Ratio                6.983  ...  16.7912
#     SGA-to-Revenue Ratio                          0.0955  ...      0.0
#     Fixed Asset Turnover                          0.5622  ...    0.492
#     Asset Turnover Ratio                           0.504  ...   0.4534
#     Operating Ratio                               0.7894  ...    0.661
# WAB Days of Inventory Outstanding (DIO)          63.0284  ...  82.0444
#     Days of Sales Outstanding (DSO)              45.8482  ...   67.159
#     Operating Cycle (CC)                        108.8766  ... 149.2034
#     Days of Accounts Payable Outstanding (DPO)   26.3402  ...  58.2483
#     Cash Conversion Cycle (CCC)                  82.5363  ...   90.955
#     Receivables Turnover                          0.1256  ...    0.184
#     Inventory Turnover Ratio                       5.791  ...   4.4488
#     Accounts Payable Turnover Ratio              13.8571  ...   6.2663
#     SGA-to-Revenue Ratio                          0.0829  ...   0.1024
#     Fixed Asset Turnover                          3.5226  ...   1.8681
#     Asset Turnover Ratio                           1.913  ...   0.9921
#     Operating Ratio                               0.7433  ...   0.8296
#
# date                                               2014     2015     2016  \
# CSX Days of Inventory Outstanding (DIO)           10.58    13.82  17.9886
#     Days of Sales Outstanding (DSO)             31.4178  32.6185   31.656
#     Operating Cycle (CC)                        41.9978  46.4386  49.6446
#     Days of Accounts Payable Outstanding (DPO)  36.3146  35.6925  37.3079
#     Cash Conversion Cycle (CCC)                  5.6832   10.746  12.3366
#     Receivables Turnover                         0.0861   0.0894   0.0867
#     Inventory Turnover Ratio                     34.499  26.4109  20.2906
#     Accounts Payable Turnover Ratio             10.0511  10.2262   9.7834
#     SGA-to-Revenue Ratio                            0.0      0.0      0.0
#     Fixed Asset Turnover                         0.4247   0.3776   0.3406
#     Asset Turnover Ratio                         0.3908   0.3469   0.3142
#     Operating Ratio                              0.7129   0.7049    0.698
# NSC Days of Inventory Outstanding (DIO)         11.7833  13.9118    16.02
#     Days of Sales Outstanding (DSO)             32.6409  34.7429  34.9016
#     Operating Cycle (CC)                        44.4242  48.6547  50.9216
#     Days of Accounts Payable Outstanding (DPO)  64.1279  63.7694  69.9659
#     Cash Conversion Cycle (CCC)                -19.7037 -15.1147 -19.0443
#     Receivables Turnover                         0.0894   0.0952   0.0956
#     Inventory Turnover Ratio                     30.976  26.2367  22.7841
#     Accounts Payable Turnover Ratio              5.6918   5.7238   5.2168
#     SGA-to-Revenue Ratio                         0.0095   0.0131    0.002
#     Fixed Asset Turnover                         0.3883   0.3386   0.3079
#     Asset Turnover Ratio                         0.3537   0.3114    0.286
#     Operating Ratio                              0.6924   0.7256   0.6891
# UNP Days of Inventory Outstanding (DIO)         17.4071  20.5858  22.7187
#     Days of Sales Outstanding (DSO)             23.0141  24.8236  23.9233
#     Operating Cycle (CC)                        40.4212  45.4094   46.642
#     Days of Accounts Payable Outstanding (DPO)  21.4241  23.0311  26.5494
#     Cash Conversion Cycle (CCC)                 18.9971  22.3783  20.0926
#     Receivables Turnover                         0.0631    0.068   0.0655
#     Inventory Turnover Ratio                    20.9685  17.7307  16.0661
#     Accounts Payable Turnover Ratio             17.0369  15.8481  13.7479
#     SGA-to-Revenue Ratio                            0.0      0.0      0.0
#     Fixed Asset Turnover                         0.5116   0.4429   0.3887
#     Asset Turnover Ratio                         0.4683   0.4065   0.3615
#     Operating Ratio                              0.6351   0.6309   0.6353
# WAB Days of Inventory Outstanding (DIO)         79.1272  79.8997 103.3997
#     Days of Sales Outstanding (DSO)             71.0786  67.8591  95.9634
#     Operating Cycle (CC)                       150.2058 147.7588  199.363
#     Days of Accounts Payable Outstanding (DPO)  62.8836   58.086  77.2699
#     Cash Conversion Cycle (CCC)                 87.3222  89.6728 122.0931
#     Receivables Turnover                         0.1947   0.1859   0.2629
#     Inventory Turnover Ratio                     4.6128   4.5682     3.53
#     Accounts Payable Turnover Ratio              5.8044   6.2838   4.7237
#     SGA-to-Revenue Ratio                         0.1066    0.105   0.1268
#     Fixed Asset Turnover                           1.93   1.9726   1.0854
#     Asset Turnover Ratio                          0.994   1.0018   0.5933
#     Operating Ratio                              0.8269   0.8163   0.8436
#
# date                                               2017     2018     2019  \
# CSX Days of Inventory Outstanding (DIO)         18.6205  15.4992  13.5396
#     Days of Sales Outstanding (DSO)             30.5233   29.498   30.516
#     Operating Cycle (CC)                        49.1438  44.9972  44.0556
#     Days of Accounts Payable Outstanding (DPO)  39.5118  43.8371   51.471
#     Cash Conversion Cycle (CCC)                   9.632   1.1601  -7.4154
#     Receivables Turnover                         0.0836   0.0808   0.0836
#     Inventory Turnover Ratio                    19.6021  23.5496   26.958
#     Accounts Payable Turnover Ratio              9.2377   8.3263   7.0914
#     SGA-to-Revenue Ratio                            0.0      0.0      0.0
#     Fixed Asset Turnover                         0.3418   0.3604   0.3453
#     Asset Turnover Ratio                         0.3207   0.3381   0.3184
#     Operating Ratio                              0.6711   0.6164   0.5991
# NSC Days of Inventory Outstanding (DIO)         14.0452  11.4396  12.5335
#     Days of Sales Outstanding (DSO)             32.8642  31.2821  31.1652
#     Operating Cycle (CC)                        46.9094  42.7217  43.6987
#     Days of Accounts Payable Outstanding (DPO)  76.7063  77.4905  81.5094
#     Cash Conversion Cycle (CCC)                -29.7969 -34.7688 -37.8107
#     Receivables Turnover                           0.09   0.0857   0.0854
#     Inventory Turnover Ratio                    25.9875  31.9068   29.122
#     Accounts Payable Turnover Ratio              4.7584   4.7103    4.478
#     SGA-to-Revenue Ratio                         0.0106  -0.0053  -0.0056
#     Fixed Asset Turnover                         0.3189   0.3373   0.3217
#     Asset Turnover Ratio                         0.2989   0.3185   0.3046
#     Operating Ratio                              0.6601   0.6545   0.6469
# UNP Days of Inventory Outstanding (DIO)         21.8743    20.47  22.5296
#     Days of Sales Outstanding (DSO)             23.6374  25.9618  28.1636
#     Operating Cycle (CC)                        45.5117  46.4318  50.6931
#     Days of Accounts Payable Outstanding (DPO)  29.3647  25.8792  24.4611
#     Cash Conversion Cycle (CCC)                  16.147  20.5526   26.232
#     Receivables Turnover                         0.0648   0.0711   0.0772
#     Inventory Turnover Ratio                    16.6862   17.831  16.2009
#     Accounts Payable Turnover Ratio             12.4299   14.104  14.9217
#     SGA-to-Revenue Ratio                            0.0      0.0      0.0
#     Fixed Asset Turnover                         0.4012   0.4199   0.3835
#     Asset Turnover Ratio                         0.3742   0.3904   0.3593
#     Operating Ratio                              0.6205    0.627    0.606
# WAB Days of Inventory Outstanding (DIO)         90.7914  92.5731  80.6792
#     Days of Sales Outstanding (DSO)             99.1681   96.762  62.5547
#     Operating Cycle (CC)                       189.9595 189.3351  143.234
#     Days of Accounts Payable Outstanding (DPO)  70.1592  66.5919  53.8362
#     Cash Conversion Cycle (CCC)                119.8003 122.7431  89.3977
#     Receivables Turnover                         0.2717   0.2651   0.1714
#     Inventory Turnover Ratio                     4.0202   3.9428   4.5241
#     Accounts Payable Turnover Ratio              5.2025   5.4811   6.7798
#     SGA-to-Revenue Ratio                          0.132   0.1451   0.1423
#     Fixed Asset Turnover                          0.967    1.025    0.868
#     Asset Turnover Ratio                         0.5899    0.573   0.5956
#     Operating Ratio                              0.8915   0.8915   0.9191
#
# date                                               2020     2021     2022
# CSX Days of Inventory Outstanding (DIO)         16.5162   15.847  13.6855
#     Days of Sales Outstanding (DSO)             32.7303  30.0232  30.2385
#     Operating Cycle (CC)                        49.2466  45.8702   43.924
#     Days of Accounts Payable Outstanding (DPO)  54.3305  43.8079  42.1231
#     Cash Conversion Cycle (CCC)                 -5.0839   2.0622   1.8009
#     Receivables Turnover                         0.0897   0.0823   0.0828
#     Inventory Turnover Ratio                    22.0995  23.0328  26.6706
#     Accounts Payable Turnover Ratio              6.7181   8.3318   8.6651
#     SGA-to-Revenue Ratio                            0.0      0.0      0.0
#     Fixed Asset Turnover                         0.3009   0.3478   0.3976
#     Asset Turnover Ratio                         0.2712   0.3118   0.3603
#     Operating Ratio                              0.5896   0.5958   0.6195
# NSC Days of Inventory Outstanding (DIO)         14.7613  13.0315  11.9005
#     Days of Sales Outstanding (DSO)             32.9615  29.8761  30.4143
#     Operating Cycle (CC)                        47.7228  42.9076  42.3148
#     Days of Accounts Payable Outstanding (DPO)  77.5839  70.2631  66.8047
#     Cash Conversion Cycle (CCC)                -29.8612 -27.3555 -24.4898
#     Receivables Turnover                         0.0903   0.0819   0.0833
#     Inventory Turnover Ratio                    24.7269  28.0091  30.6709
#     Accounts Payable Turnover Ratio              4.7046   5.1948   5.4637
#     SGA-to-Revenue Ratio                        -0.0093  -0.0092    0.006
#     Fixed Asset Turnover                         0.2739   0.3096   0.3482
#     Asset Turnover Ratio                          0.258   0.2915   0.3294
#     Operating Ratio                               0.654   0.6009   0.6227
# UNP Days of Inventory Outstanding (DIO)         24.4826  20.3514  18.1832
#     Days of Sales Outstanding (DSO)             28.9638  27.0101  26.5074
#     Operating Cycle (CC)                        53.4464  47.3615  44.6907
#     Days of Accounts Payable Outstanding (DPO)   23.989  22.0487  20.5062
#     Cash Conversion Cycle (CCC)                 29.4573  25.3128  24.1845
#     Receivables Turnover                         0.0794    0.074   0.0726
#     Inventory Turnover Ratio                    14.9086  17.9349  20.0734
#     Accounts Payable Turnover Ratio             15.2153  16.5543  17.7995
#     SGA-to-Revenue Ratio                            0.0      0.0      0.0
#     Fixed Asset Turnover                         0.3356   0.3691   0.4096
#     Asset Turnover Ratio                         0.3149   0.3463   0.3857
#     Operating Ratio                              0.5989   0.5717   0.6013
# WAB Days of Inventory Outstanding (DIO)        115.0164 111.4846 116.7035
#     Days of Sales Outstanding (DSO)             74.3033  67.4167  65.3875
#     Operating Cycle (CC)                       189.3197 178.9014 182.0909
#     Days of Accounts Payable Outstanding (DPO)  69.6086  64.3051  72.5047
#     Cash Conversion Cycle (CCC)                119.7111 114.5963 109.5862
#     Receivables Turnover                         0.2036   0.1847   0.1791
#     Inventory Turnover Ratio                     3.1735    3.274   3.1276
#     Accounts Payable Turnover Ratio              5.2436   5.6761   5.0342
#     SGA-to-Revenue Ratio                         0.1255   0.1317   0.1231
#     Fixed Asset Turnover                         0.5163   0.5358   0.5805
#     Asset Turnover Ratio                         0.4047   0.4239   0.4524
#     Operating Ratio                              0.9015    0.888   0.8791
#
# [48 rows x 38 columns]
