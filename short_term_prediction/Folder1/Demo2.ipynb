# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score
from math import sqrt

# %%
ticker = 'TATAMOTORS.NS'
start_date = '2018-01-01'
end_date = '2023-10-31'

# %%
df = yf.download(ticker, start_date, end_date).reset_index()
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-01-01  430.950012  436.399994  422.250000  424.450012  423.131256
# 1    2018-01-02  428.850006  440.850006  422.000000  439.299988  437.935089
# 2    2018-01-03  440.399994  441.399994  431.950012  433.899994  432.551849
# 3    2018-01-04  430.000000  433.299988  425.750000  429.950012  428.614166
# 4    2018-01-05  431.250000  436.350006  429.799988  431.600006  430.259033
# ...         ...         ...         ...         ...         ...         ...
# 1435 2023-10-23  663.650024  667.250000  645.000000  647.349976  647.349976
# 1436 2023-10-25  650.000000  651.900024  636.049988  637.849976  637.849976
# 1437 2023-10-26  635.000000  635.650024  624.150024  626.549988  626.549988
# 1438 2023-10-27  630.000000  643.950012  628.450012  641.049988  641.049988
# 1439 2023-10-30  643.799988  643.799988  621.849976  628.500000  628.500000
#
#         Volume
# 0      6807536
# 1     15331261
# 2      9794953
# 3      8395377
# 4      7021611
# ...        ...
# 1435   8564004
# 1436   8229559
# 1437   8889373
# 1438  10232856
# 1439  12786883
#
# [1440 rows x 7 columns]

# %%
data = df['Close']

scaler = MinMaxScaler()
data = scaler.fit_transform(data.values.reshape(-1, 1))
data
# Out:
# array([[0.59511188],
#        [0.6197183 ],
#        [0.61077051],
#        ...,
#        [0.92999171],
#        [0.95401823],
#        [0.93322289]])

# %%
training_data_len = int(len(data) * 0.8)
training_data = data[0:training_data_len, :]
testing_data = data[training_data_len:, :]

len(training_data), len(testing_data)
# Out:
# (1152, 288)

# %%
past_values = 1

def create_training_data(data, past_values):
    if len(data) < past_values:
        return np.array([]), np.array([])
    X_train = []
    y_train = []
    for i in range(past_values, len(data)):
        X_train.append(data[i-past_values:i, 0])
        y_train.append(data[i, 0])
    return np.array(X_train), np.array(y_train)

X_train, y_train = create_training_data(training_data, past_values)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test, y_test = create_training_data(testing_data, past_values)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=200, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 15s 14ms/step - loss: 0.1353
# Epoch 2/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1001
# Epoch 3/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0686
# Epoch 4/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0460
# Epoch 5/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0384
# Epoch 6/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0403
# Epoch 7/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0365
# Epoch 8/200
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0328
# Epoch 9/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0295
# Epoch 10/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0243
# Epoch 11/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0183
# Epoch 12/200
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0111
# Epoch 13/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0043
# Epoch 14/200
# 6/6 [==============================] - 0s 15ms/step - loss: 7.1693e-04
# Epoch 15/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 16/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0012
# Epoch 17/200
# 6/6 [==============================] - 0s 15ms/step - loss: 5.3566e-04
# Epoch 18/200
# 6/6 [==============================] - 0s 14ms/step - loss: 3.9296e-04
# Epoch 19/200
# 6/6 [==============================] - 0s 13ms/step - loss: 4.6647e-04
# Epoch 20/200
# 6/6 [==============================] - 0s 15ms/step - loss: 4.1876e-04
# Epoch 21/200
# 6/6 [==============================] - 0s 13ms/step - loss: 3.5341e-04
# Epoch 22/200
# 6/6 [==============================] - 0s 12ms/step - loss: 3.5646e-04
# Epoch 23/200
# 6/6 [==============================] - 0s 15ms/step - loss: 3.4903e-04
# Epoch 24/200
# 6/6 [==============================] - 0s 17ms/step - loss: 3.3392e-04
# Epoch 25/200
# 6/6 [==============================] - 0s 13ms/step - loss: 3.2646e-04
# Epoch 26/200
# 6/6 [==============================] - 0s 16ms/step - loss: 3.1780e-04
# Epoch 27/200
# 6/6 [==============================] - 0s 13ms/step - loss: 3.1274e-04
# Epoch 28/200
# 6/6 [==============================] - 0s 13ms/step - loss: 3.0573e-04
# Epoch 29/200
# 6/6 [==============================] - 0s 13ms/step - loss: 3.0029e-04
# Epoch 30/200
# 6/6 [==============================] - 0s 13ms/step - loss: 2.9620e-04
# Epoch 31/200
# 6/6 [==============================] - 0s 12ms/step - loss: 2.8834e-04
# Epoch 32/200
# 6/6 [==============================] - 0s 13ms/step - loss: 2.8447e-04
# Epoch 33/200
# 6/6 [==============================] - 0s 13ms/step - loss: 2.7996e-04
# Epoch 34/200
# 6/6 [==============================] - 0s 12ms/step - loss: 2.7446e-04
# Epoch 35/200
# 6/6 [==============================] - 0s 12ms/step - loss: 2.6999e-04
# Epoch 36/200
# 6/6 [==============================] - 0s 10ms/step - loss: 2.6499e-04
# Epoch 37/200
# 6/6 [==============================] - 0s 13ms/step - loss: 2.6084e-04
# Epoch 38/200
# 6/6 [==============================] - 0s 15ms/step - loss: 2.5702e-04
# Epoch 39/200
# 6/6 [==============================] - 0s 13ms/step - loss: 2.5419e-04
# Epoch 40/200
# 6/6 [==============================] - 0s 14ms/step - loss: 2.4906e-04
# Epoch 41/200
# 6/6 [==============================] - 0s 13ms/step - loss: 2.4442e-04
# Epoch 42/200
# 6/6 [==============================] - 0s 12ms/step - loss: 2.4795e-04
# Epoch 43/200
# 6/6 [==============================] - 0s 14ms/step - loss: 2.4213e-04
# Epoch 44/200
# 6/6 [==============================] - 0s 14ms/step - loss: 2.3525e-04
# Epoch 45/200
# 6/6 [==============================] - 0s 14ms/step - loss: 2.3096e-04
# Epoch 46/200
# 6/6 [==============================] - 0s 12ms/step - loss: 2.2727e-04
# Epoch 47/200
# 6/6 [==============================] - 0s 16ms/step - loss: 2.2467e-04
# Epoch 48/200
# 6/6 [==============================] - 0s 16ms/step - loss: 2.2254e-04
# Epoch 49/200
# 6/6 [==============================] - 0s 16ms/step - loss: 2.2183e-04
# Epoch 50/200
# 6/6 [==============================] - 0s 17ms/step - loss: 2.1694e-04
# Epoch 51/200
# 6/6 [==============================] - 0s 15ms/step - loss: 2.1417e-04
# Epoch 52/200
# 6/6 [==============================] - 0s 12ms/step - loss: 2.1165e-04
# Epoch 53/200
# 6/6 [==============================] - 0s 15ms/step - loss: 2.0944e-04
# Epoch 54/200
# 6/6 [==============================] - 0s 18ms/step - loss: 2.0803e-04
# Epoch 55/200
# 6/6 [==============================] - 0s 19ms/step - loss: 2.0568e-04
# Epoch 56/200
# 6/6 [==============================] - 0s 17ms/step - loss: 2.0362e-04
# Epoch 57/200
# 6/6 [==============================] - 0s 17ms/step - loss: 2.0394e-04
# Epoch 58/200
# 6/6 [==============================] - 0s 14ms/step - loss: 2.0169e-04
# Epoch 59/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1.9997e-04
# Epoch 60/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9860e-04
# Epoch 61/200
# 6/6 [==============================] - 0s 14ms/step - loss: 2.0038e-04
# Epoch 62/200
# 6/6 [==============================] - 0s 14ms/step - loss: 1.9640e-04
# Epoch 63/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9526e-04
# Epoch 64/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9241e-04
# Epoch 65/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1.9169e-04
# Epoch 66/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9123e-04
# Epoch 67/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1.9378e-04
# Epoch 68/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9013e-04
# Epoch 69/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.8774e-04
# Epoch 70/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.8677e-04
# Epoch 71/200
# 6/6 [==============================] - 0s 21ms/step - loss: 1.8581e-04
# Epoch 72/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.8559e-04
# Epoch 73/200
# 6/6 [==============================] - 0s 14ms/step - loss: 1.8547e-04
# Epoch 74/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.8596e-04
# Epoch 75/200
# 6/6 [==============================] - 0s 23ms/step - loss: 1.8674e-04
# Epoch 76/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8586e-04
# Epoch 77/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8504e-04
# Epoch 78/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8350e-04
# Epoch 79/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8256e-04
# Epoch 80/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8243e-04
# Epoch 81/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8385e-04
# Epoch 82/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1.8206e-04
# Epoch 83/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1.8167e-04
# Epoch 84/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1.8419e-04
# Epoch 85/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8762e-04
# Epoch 86/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8422e-04
# Epoch 87/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8311e-04
# Epoch 88/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8026e-04
# Epoch 89/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8097e-04
# Epoch 90/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8077e-04
# Epoch 91/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7920e-04
# Epoch 92/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.8000e-04
# Epoch 93/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8027e-04
# Epoch 94/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.8163e-04
# Epoch 95/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7992e-04
# Epoch 96/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.8232e-04
# Epoch 97/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.7848e-04
# Epoch 98/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.8009e-04
# Epoch 99/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.7877e-04
# Epoch 100/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7860e-04
# Epoch 101/200
# 6/6 [==============================] - 0s 21ms/step - loss: 1.7936e-04
# Epoch 102/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7882e-04
# Epoch 103/200
# 6/6 [==============================] - 0s 29ms/step - loss: 1.7864e-04
# Epoch 104/200
# 6/6 [==============================] - 0s 24ms/step - loss: 1.7866e-04
# Epoch 105/200
# 6/6 [==============================] - 0s 24ms/step - loss: 1.7975e-04
# Epoch 106/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7950e-04
# Epoch 107/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.8064e-04
# Epoch 108/200
# 6/6 [==============================] - 0s 28ms/step - loss: 1.8014e-04
# Epoch 109/200
# 6/6 [==============================] - 0s 25ms/step - loss: 1.8587e-04
# Epoch 110/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8178e-04
# Epoch 111/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7775e-04
# Epoch 112/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7934e-04
# Epoch 113/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.7952e-04
# Epoch 114/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7728e-04
# Epoch 115/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.7754e-04
# Epoch 116/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.7807e-04
# Epoch 117/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7742e-04
# Epoch 118/200
# 6/6 [==============================] - 0s 24ms/step - loss: 1.7732e-04
# Epoch 119/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7805e-04
# Epoch 120/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7753e-04
# Epoch 121/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7933e-04
# Epoch 122/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7829e-04
# Epoch 123/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7879e-04
# Epoch 124/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.8244e-04
# Epoch 125/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.8189e-04
# Epoch 126/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8184e-04
# Epoch 127/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7797e-04
# Epoch 128/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7953e-04
# Epoch 129/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7967e-04
# Epoch 130/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7877e-04
# Epoch 131/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7806e-04
# Epoch 132/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7854e-04
# Epoch 133/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7838e-04
# Epoch 134/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7752e-04
# Epoch 135/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7749e-04
# Epoch 136/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7709e-04
# Epoch 137/200
# 6/6 [==============================] - 0s 21ms/step - loss: 1.8086e-04
# Epoch 138/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.7909e-04
# Epoch 139/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7892e-04
# Epoch 140/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8186e-04
# Epoch 141/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.7937e-04
# Epoch 142/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7860e-04
# Epoch 143/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7796e-04
# Epoch 144/200
# 6/6 [==============================] - 0s 26ms/step - loss: 1.8125e-04
# Epoch 145/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.8418e-04
# Epoch 146/200
# 6/6 [==============================] - 0s 21ms/step - loss: 1.7934e-04
# Epoch 147/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.7929e-04
# Epoch 148/200
# 6/6 [==============================] - 0s 24ms/step - loss: 1.8599e-04
# Epoch 149/200
# 6/6 [==============================] - 0s 23ms/step - loss: 1.8240e-04
# Epoch 150/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7803e-04
# Epoch 151/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7779e-04
# Epoch 152/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.7951e-04
# Epoch 153/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7784e-04
# Epoch 154/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.7908e-04
# Epoch 155/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.8176e-04
# Epoch 156/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8930e-04
# Epoch 157/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7786e-04
# Epoch 158/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8002e-04
# Epoch 159/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7927e-04
# Epoch 160/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8401e-04
# Epoch 161/200
# 6/6 [==============================] - 0s 14ms/step - loss: 1.8286e-04
# Epoch 162/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.8430e-04
# Epoch 163/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.9876e-04
# Epoch 164/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8134e-04
# Epoch 165/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7942e-04
# Epoch 166/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7804e-04
# Epoch 167/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7951e-04
# Epoch 168/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7786e-04
# Epoch 169/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7981e-04
# Epoch 170/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7844e-04
# Epoch 171/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7725e-04
# Epoch 172/200
# 6/6 [==============================] - 0s 21ms/step - loss: 1.7787e-04
# Epoch 173/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8234e-04
# Epoch 174/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.7999e-04
# Epoch 175/200
# 6/6 [==============================] - 0s 14ms/step - loss: 1.8928e-04
# Epoch 176/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.8147e-04
# Epoch 177/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8777e-04
# Epoch 178/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9291e-04
# Epoch 179/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.8697e-04
# Epoch 180/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.7926e-04
# Epoch 181/200
# 6/6 [==============================] - 0s 34ms/step - loss: 1.8008e-04
# Epoch 182/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.8167e-04
# Epoch 183/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.7854e-04
# Epoch 184/200
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7937e-04
# Epoch 185/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.7714e-04
# Epoch 186/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.7889e-04
# Epoch 187/200
# 6/6 [==============================] - 0s 19ms/step - loss: 1.8010e-04
# Epoch 188/200
# 6/6 [==============================] - 0s 14ms/step - loss: 1.7832e-04
# Epoch 189/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7920e-04
# Epoch 190/200
# 6/6 [==============================] - 0s 16ms/step - loss: 1.7807e-04
# Epoch 191/200
# 6/6 [==============================] - 0s 21ms/step - loss: 1.7872e-04
# Epoch 192/200
# 6/6 [==============================] - 0s 18ms/step - loss: 1.8317e-04
# Epoch 193/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8587e-04
# Epoch 194/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8471e-04
# Epoch 195/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1.8470e-04
# Epoch 196/200
# 6/6 [==============================] - 0s 29ms/step - loss: 1.8063e-04
# Epoch 197/200
# 6/6 [==============================] - 0s 29ms/step - loss: 1.8067e-04
# Epoch 198/200
# 6/6 [==============================] - 0s 14ms/step - loss: 1.7926e-04
# Epoch 199/200
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7759e-04
# Epoch 200/200
# 6/6 [==============================] - 0s 23ms/step - loss: 1.7775e-04

# %%
pred_train = model.predict(X_train)
pred = model.predict(X_test)
# Out:
# 36/36 [==============================] - 3s 4ms/step
# 9/9 [==============================] - 0s 5ms/step

# %%
pred_train, pred
# Out:
# (array([[0.5949373 ],
#         [0.61931515],
#         [0.6104568 ],
#         ...,
#         [0.6518928 ],
#         [0.6614484 ],
#         [0.6423272 ]], dtype=float32),
#  array([[0.6644682 ],
#         [0.65605915],
#         [0.65156573],
#         [0.64952266],
#         [0.6300498 ],
#         [0.62406933],
#         [0.63013166],
#         [0.638482  ],
#         [0.6479695 ],
#         [0.63717246],
#         [0.63234276],
#         [0.6081591 ],
#         [0.5965805 ],
#         [0.6110313 ],
#         [0.6001951 ],
#         [0.6076667 ],
#         [0.5927184 ],
#         [0.5505632 ],
#         [0.5527073 ],
#         [0.55320203],
#         [0.5583958 ],
#         [0.56226903],
#         [0.55081064],
#         [0.56770617],
#         [0.5779149 ],
#         [0.57470506],
#         [0.54800624],
#         [0.54371625],
#         [0.54899615],
#         [0.55303717],
#         [0.54850113],
#         [0.5482537 ],
#         [0.56169236],
#         [0.5531196 ],
#         [0.55155283],
#         [0.55147034],
#         [0.5573243 ],
#         [0.5621867 ],
#         [0.5673768 ],
#         [0.57100034],
#         [0.57569283],
#         [0.58984137],
#         [0.5911567 ],
#         [0.58145297],
#         [0.5964162 ],
#         [0.612262  ],
#         [0.609226  ],
#         [0.5747874 ],
#         [0.5933758 ],
#         [0.61012864],
#         [0.6157891 ],
#         [0.60659957],
#         [0.5928005 ],
#         [0.5938689 ],
#         [0.58943033],
#         [0.59534806],
#         [0.5942799 ],
#         [0.5932115 ],
#         [0.6093081 ],
#         [0.6093901 ],
#         [0.609226  ],
#         [0.61947924],
#         [0.6175933 ],
#         [0.6129182 ],
#         [0.60200185],
#         [0.59929156],
#         [0.587786  ],
#         [0.58301604],
#         [0.57659805],
#         [0.57799715],
#         [0.58515453],
#         [0.5841676 ],
#         [0.58219343],
#         [0.5902525 ],
#         [0.58433205],
#         [0.5719884 ],
#         [0.5589728 ],
#         [0.5455314 ],
#         [0.51894   ],
#         [0.52959883],
#         [0.5450364 ],
#         [0.5403326 ],
#         [0.53141594],
#         [0.53480166],
#         [0.54610884],
#         [0.5446238 ],
#         [0.53092045],
#         [0.5330676 ],
#         [0.5249727 ],
#         [0.5372785 ],
#         [0.5759398 ],
#         [0.584661  ],
#         [0.57486963],
#         [0.5736349 ],
#         [0.57610434],
#         [0.5798897 ],
#         [0.56852984],
#         [0.5559228 ],
#         [0.55987924],
#         [0.56852984],
#         [0.5911567 ],
#         [0.5860592 ],
#         [0.6296403 ],
#         [0.6264455 ],
#         [0.64028203],
#         [0.6313601 ],
#         [0.62832975],
#         [0.62939465],
#         [0.6237415 ],
#         [0.61300033],
#         [0.62062687],
#         [0.6151329 ],
#         [0.6300498 ],
#         [0.6221843 ],
#         [0.6213646 ],
#         [0.6272648 ],
#         [0.62308586],
#         [0.6202989 ],
#         [0.62538034],
#         [0.61472297],
#         [0.60315144],
#         [0.6093081 ],
#         [0.60035926],
#         [0.5842498 ],
#         [0.58877265],
#         [0.59748435],
#         [0.58836156],
#         [0.60077   ],
#         [0.62062687],
#         [0.61931515],
#         [0.6076667 ],
#         [0.6136565 ],
#         [0.5915677 ],
#         [0.5821111 ],
#         [0.5733879 ],
#         [0.58054805],
#         [0.5859769 ],
#         [0.57240003],
#         [0.57536346],
#         [0.5812062 ],
#         [0.5862237 ],
#         [0.58186436],
#         [0.5745404 ],
#         [0.5573243 ],
#         [0.5698475 ],
#         [0.58893704],
#         [0.59460855],
#         [0.59838796],
#         [0.6166093 ],
#         [0.65532404],
#         [0.65107554],
#         [0.662183  ],
#         [0.6687107 ],
#         [0.6730326 ],
#         [0.6744184 ],
#         [0.6685475 ],
#         [0.68061113],
#         [0.67148346],
#         [0.6780042 ],
#         [0.675315  ],
#         [0.6828916 ],
#         [0.6884272 ],
#         [0.69387794],
#         [0.6862297 ],
#         [0.6918446 ],
#         [0.68712515],
#         [0.68109995],
#         [0.71913165],
#         [0.7242376 ],
#         [0.7337111 ],
#         [0.737109  ],
#         [0.7441426 ],
#         [0.7681829 ],
#         [0.75254154],
#         [0.74341524],
#         [0.7320117 ],
#         [0.7586732 ],
#         [0.7547205 ],
#         [0.76439667],
#         [0.75100785],
#         [0.7423645 ],
#         [0.7481817 ],
#         [0.7530259 ],
#         [0.74874705],
#         [0.76085037],
#         [0.7751858 ],
#         [0.7763122 ],
#         [0.7929429 ],
#         [0.80817103],
#         [0.8276741 ],
#         [0.81449217],
#         [0.8186495 ],
#         [0.821606  ],
#         [0.8184897 ],
#         [0.8314237 ],
#         [0.828472  ],
#         [0.8306261 ],
#         [0.82464063],
#         [0.852045  ],
#         [0.8491036 ],
#         [0.8299081 ],
#         [0.81441224],
#         [0.8275144 ],
#         [0.8358884 ],
#         [0.8358884 ],
#         [0.87156445],
#         [0.8640343 ],
#         [0.8650654 ],
#         [0.8599878 ],
#         [0.87987536],
#         [0.9073309 ],
#         [0.90803903],
#         [0.9235167 ],
#         [0.91244346],
#         [0.9111855 ],
#         [0.9178653 ],
#         [0.907803  ],
#         [0.8977215 ],
#         [0.91110677],
#         [0.91275793],
#         [0.9192002 ],
#         [0.9246933 ],
#         [0.940668  ],
#         [0.9432474 ],
#         [0.9473092 ],
#         [0.93417466],
#         [0.94824594],
#         [0.9472311 ],
#         [0.91433   ],
#         [0.90851116],
#         [0.9022921 ],
#         [0.8936205 ],
#         [0.89014804],
#         [0.9141726 ],
#         [0.90740955],
#         [0.89724857],
#         [0.89022696],
#         [0.90819645],
#         [0.9003226 ],
#         [0.9035522 ],
#         [0.9109495 ],
#         [0.91047764],
#         [0.900559  ],
#         [0.8959081 ],
#         [0.88667333],
#         [0.8824058 ],
#         [0.88991135],
#         [0.88738424],
#         [0.8801918 ],
#         [0.89630234],
#         [0.8928316 ],
#         [0.8962236 ],
#         [0.89480394],
#         [0.90213454],
#         [0.92155504],
#         [0.9334699 ],
#         [0.91142136],
#         [0.9194357 ],
#         [0.917394  ],
#         [0.93253034],
#         [0.9425441 ],
#         [0.93918246],
#         [0.9212411 ],
#         [0.91087097],
#         [0.9081177 ],
#         [0.9098484 ],
#         [0.91039914],
#         [0.900874  ],
#         [0.9261833 ],
#         [0.91087097],
#         [0.90008605],
#         [0.90953374],
#         [0.9140156 ],
#         [0.90599287],
#         [0.926732  ],
#         [0.93213874],
#         [0.9367573 ],
#         [0.9837124 ],
#         [0.98231745],
#         [0.96601206],
#         [0.98588145],
#         [0.9863462 ],
#         [0.9776644 ],
#         [0.95300555],
#         [0.9381655 ],
#         [0.9204563 ],
#         [0.94316924]], dtype=float32))

# %%
pred_train = scaler.inverse_transform(pred_train)
pred = scaler.inverse_transform(pred)
y_test = scaler.inverse_transform([y_test])
y_train = scaler.inverse_transform([y_train])

# %%
y_test = y_test.flatten()
y_train = y_train.flatten()

# %%
print("Training Error")
mae = mean_absolute_error(y_train, pred_train)
print("Mean Absolute Error (MAE):", mae)
rmse = sqrt(mean_squared_error(y_train, pred_train))
print("Root Mean Squared Error (RMSE):", rmse)
    
plt.plot(y_train, label = 'actual '+str(ticker))
plt.plot(pred_train, label = 'predicted '+str(ticker))
plt.title("Training Plot")
plt.legend()
plt.show()
# Out:
# Training Error
# Mean Absolute Error (MAE): 5.220761044764911
# Root Mean Squared Error (RMSE): 8.038764061434998

# %%
print("Testing Error")
mae = mean_absolute_error(y_test, pred)
print("Mean Absolute Error (MAE):", mae)
rmse = sqrt(mean_squared_error(y_test, pred))
print("Root Mean Squared Error (RMSE):", rmse)

plt.plot(y_test, label = 'actual '+str(ticker))
plt.plot(pred, label = 'predicted '+str(ticker))
plt.title("Testing Plot")
plt.legend()
plt.show()
# Out:
# Testing Error
# Mean Absolute Error (MAE): 6.39784607571592
# Root Mean Squared Error (RMSE): 8.56171433030436

# %%
y_test[-1]
# Out:
# 628.5

# %%
pred[-1]
# Out:
# array([634.5027], dtype=float32)

# %%
start_date = '2023-11-01'
end_date = '2023-12-08'
future_data = yf.download(ticker, start_date, end_date).reset_index()['Close']
future_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# 0     627.700012
# 1     636.450012
# 2     647.500000
# 3     646.049988
# 4     645.000000
# 5     642.549988
# 6     649.349976
# 7     651.049988
# 8     653.250000
# 9     671.549988
# 10    680.400024
# 11    681.549988
# 12    674.299988
# 13    681.700012
# 14    681.200012
# 15    679.950012
# 16    673.700012
# 17    697.500000
# 18    712.349976
# 19    706.400024
# 20    705.450012
# 21    705.599976
# 22    708.950012
# 23    722.450012
# 24    721.950012
# Name: Close, dtype: float64

# %%
future_data = np.array(future_data)
len(future_data)
# Out:
# 25

# %%
# model(april1) = (april2-pred) -> april2actual



# model(april2-pred) = april3-pred

# %%
def predict_future(days, last_input, future_data):
    Output = []
    i = 0
    temp = scaler.transform(future_data.reshape(-1, 1))
    
    while(i<days):
        if(len(last_input)>past_values):
            last_input = last_input[1:]
            last_input = last_input.reshape((1, past_values, 1))
            res = model.predict(last_input)
            last_input = np.append(last_input, temp[i])
            last_input = last_input[1:]
            Output.extend(res.tolist())
            i=i+1
        else:
            last_input = last_input.reshape((1, past_values, 1))
            res = model.predict(last_input)
            last_input = np.append(last_input, temp[i])
            Output.extend(res.tolist())
            i=i+1
        
    Output = scaler.inverse_transform(Output)
    return Output, last_input
    
future_predictions, last_input = predict_future(len(future_data), X_test[-1], future_data)
future_predictions = future_predictions.flatten()
# Out:
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 48ms/step

# %%
future_data
# Out:
# array([627.70001221, 636.45001221, 647.5       , 646.04998779,
#        645.        , 642.54998779, 649.34997559, 651.04998779,
#        653.25      , 671.54998779, 680.40002441, 681.54998779,
#        674.29998779, 681.70001221, 681.20001221, 679.95001221,
#        673.70001221, 697.5       , 712.34997559, 706.40002441,
#        705.45001221, 705.59997559, 708.95001221, 722.45001221,
#        721.95001221])

# %%
future_predictions
# Out:
# array([634.5026227 , 621.88464617, 630.16083848, 640.58006304,
#        639.21491236, 638.22598657, 635.91716212, 642.32082711,
#        643.91975594, 645.98739214, 663.12920415, 671.3814395 ,
#        672.45194843, 665.69612341, 672.59158941, 672.12619141,
#        670.96251655, 665.13640839, 687.25525958, 700.96230628,
#        695.47896961, 694.60256237, 694.74098033, 697.83049212,
#        710.2424964 ])

# %%
plt.plot(future_data, label = 'actual')
plt.plot(future_predictions, label = 'predicted')
plt.title('Tata Motors Limited')
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
def get_control_vector(val):
    return np.diff(np.sign(np.diff(val)))

def buy_and_sell_bot(val,controls):
    print('val', val)
    print('controls', controls)
    inv = []
    curr_val = 1000
    inds = np.where(controls)[0]
    buy_inds = np.where(controls>0)[0]
    sell_inds = np.where(controls<0)[0]
    max_limit = sell_inds[-1] if sell_inds[-1]>buy_inds[-1] else buy_inds[-1]
    for i in range(buy_inds[0]+2):
        inv.append(curr_val)
    for i in range(buy_inds[0],max_limit+1):
        if controls[i]>0:
            buy_val = val[i+1]
        elif controls[i]<0:
            sell_val = val[i+1]
            curr_val = curr_val*sell_val/buy_val
        inv.append(curr_val)
        
    if max_limit+1!=len(controls):
        for i in range(len(controls)-max_limit-1):
            inv.append(curr_val)
    return inv

# %%
controls_actual = get_control_vector(future_data)
amount_actual = buy_and_sell_bot(future_data, controls_actual)
print('amount_actual',amount_actual)
# Out:
# val [627.70001221 636.45001221 647.5        646.04998779 645.
#  642.54998779 649.34997559 651.04998779 653.25       671.54998779
#  680.40002441 681.54998779 674.29998779 681.70001221 681.20001221
#  679.95001221 673.70001221 697.5        712.34997559 706.40002441
#  705.45001221 705.59997559 708.95001221 722.45001221 721.95001221]
# controls [ 0. -2.  0.  0.  2.  0.  0.  0.  0.  0. -2.  2. -2.  0.  0.  2.  0. -2.
#   0.  2.  0.  0. -2.]
# amount_actual [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1060.6956668600326, 1060.6956668600326, 1072.3361443518763, 1072.3361443518763, 1072.3361443518763, 1072.3361443518763, 1072.3361443518763, 1133.855740549154, 1133.855740549154, 1133.855740549154, 1133.855740549154, 1133.855740549154, 1161.179501631858]

# %%
controls_pred= get_control_vector(future_predictions)
amount_pred = buy_and_sell_bot(future_predictions, controls_pred)
print('amount_pred',amount_pred)
# Out:
# val [634.5026227  621.88464617 630.16083848 640.58006304 639.21491236
#  638.22598657 635.91716212 642.32082711 643.91975594 645.98739214
#  663.12920415 671.3814395  672.45194843 665.69612341 672.59158941
#  672.12619141 670.96251655 665.13640839 687.25525958 700.96230628
#  695.47896961 694.60256237 694.74098033 697.83049212 710.2424964 ]
# controls [ 2.  0. -2.  0.  0.  2.  0.  0.  0.  0.  0. -2.  2. -2.  0.  0.  2.  0.
#  -2.  0.  2.  0.  0.]
# amount_pred [1000, 1000, 1000, 1000, 1030.06251559188, 1030.06251559188, 1030.06251559188, 1030.06251559188, 1030.06251559188, 1030.06251559188, 1030.06251559188, 1030.06251559188, 1030.06251559188, 1089.2417863192395, 1089.2417863192395, 1100.5244563602837, 1100.5244563602837, 1100.5244563602837, 1100.5244563602837, 1100.5244563602837, 1159.801435190676, 1159.801435190676, 1159.801435190676, 1159.801435190676, 1159.801435190676]

# %%
plt.plot(amount_actual, label="actual")
plt.plot(amount_pred, label="pred")
plt.legend()
plt.title("Returns")
plt.show()
